# %%
#lendo os dados do MovieLens
# Out:
# Olá mundo

# %%
import pandas as pd

# %% [markdown]
# #Lendo dados do MovieLens

# %%
filmes = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula0/ml-latest-small/movies.csv")

# %%
filmes.head()
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
avaliacoes = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula0/ml-latest-small/ratings.csv")
avaliacoes.head()
print(avaliacoes.head())
print(avaliacoes.shape)

avaliacoes.columns = ["usuarioID", "filmeId", "nota", "momento"]
print("As avaliações do filme um são")
print(avaliacoes.query("filmeId==1").describe())
print("A média das notas é")
print(avaliacoes.query("filmeId==1")["nota"].mean())
print("Descrição das avaliações")
print(avaliacoes.describe())

avaliacoes.groupby("filmeId").mean()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# (100836, 4)
# As avaliações do filme um são
#         usuarioID  filmeId        nota       momento
# count  215.000000    215.0  215.000000  2.150000e+02
# mean   306.530233      1.0    3.920930  1.129835e+09
# std    180.419754      0.0    0.834859  2.393163e+08
# min      1.000000      1.0    0.500000  8.293223e+08
# 25%    155.500000      1.0    3.500000  8.779224e+08
# 50%    290.000000      1.0    4.000000  1.106855e+09
# 75%    468.500000      1.0    4.500000  1.348523e+09
# max    610.000000      1.0    5.000000  1.535710e+09
# A média das notas é
# 3.9209302325581397
# Descrição das avaliações
#            usuarioID        filmeId           nota       momento
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09
#           usuarioID      nota       momento
# filmeId
# 1        306.530233  3.920930  1.129835e+09
# 2        329.554545  3.431818  1.135805e+09
# 3        283.596154  3.259615  1.005110e+09
# 4        219.857143  2.357143  8.985789e+08
# 5        299.571429  3.071429  9.926643e+08
# ...             ...       ...           ...
# 193581   184.000000  4.000000  1.537109e+09
# 193583   184.000000  3.500000  1.537110e+09
# 193585   184.000000  3.500000  1.537110e+09
# 193587   184.000000  3.500000  1.537110e+09
# 193609   331.000000  4.000000  1.537158e+09
#
# [9724 rows x 3 columns]

# %%
print(avaliacoes.groupby("filmeId")["nota"].mean())
# Out:
# filmeId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 4         2.357143
# 5         3.071429
#             ...
# 193581    4.000000
# 193583    3.500000
# 193585    3.500000
# 193587    3.500000
# 193609    4.000000
# Name: nota, Length: 9724, dtype: float64

# %%
avaliacoes.groupby("filmeId").mean()

# %%
import pandas as pd

filmes = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula0/ml-latest-small/movies.csv")
#filmes é um DataFrame
filmes.head()
filmes.columns = ["filmeId", "titulo", "genero"]
print(filmes.head())

avaliacoes = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula0/ml-latest-small/ratings.csv")
avaliacoes.head()
print(avaliacoes.head())
print(avaliacoes.shape)

avaliacoes.columns = ["usuarioID", "filmeId", "nota", "momento"]
print("As avaliações do filme um são")
print(avaliacoes.query("filmeId==1").describe())
print("A média das notas é")
print(avaliacoes.query("filmeId==1")["nota"].mean())
print("Descrição das avaliações")
print(avaliacoes.describe())

notas_medias_por_filme = avaliacoes.groupby("filmeId")["nota"].mean()

#não queremos correr o risco de amanhã os filmes não estarem em quantidade exata e ter que alterar o meu código
#filmes["nota_media"] = notas_medias_por_filme
#print(filmes.head())

filmes_com_media = filmes.join(notas_medias_por_filme, on="filmeId")
print(filmes_com_media.head())

filmes_com_media.sort_values("nota", ascending=False)
# Out:
#    filmeId  ...                                       genero
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931
# (100836, 4)
# As avaliações do filme um são
#         usuarioID  filmeId        nota       momento
# count  215.000000    215.0  215.000000  2.150000e+02
# mean   306.530233      1.0    3.920930  1.129835e+09
# std    180.419754      0.0    0.834859  2.393163e+08
# min      1.000000      1.0    0.500000  8.293223e+08
# 25%    155.500000      1.0    3.500000  8.779224e+08
# 50%    290.000000      1.0    4.000000  1.106855e+09
# 75%    468.500000      1.0    4.500000  1.348523e+09
# max    610.000000      1.0    5.000000  1.535710e+09
# A média das notas é
# 3.9209302325581397
# Descrição das avaliações
#            usuarioID        filmeId           nota       momento
# count  100836.000000  100836.000000  100836.000000  1.008360e+05
# mean      326.127564   19435.295718       3.501557  1.205946e+09
# std       182.618491   35530.987199       1.042529  2.162610e+08
# min         1.000000       1.000000       0.500000  8.281246e+08
# 25%       177.000000    1199.000000       3.000000  1.019124e+09
# 50%       325.000000    2991.000000       3.500000  1.186087e+09
# 75%       477.000000    8122.000000       4.000000  1.435994e+09
# max       610.000000  193609.000000       5.000000  1.537799e+09
#    filmeId  ...      nota
# 0        1  ...  3.920930
# 1        2  ...  3.431818
# 2        3  ...  3.259615
# 3        4  ...  2.357143
# 4        5  ...  3.071429
#
# [5 rows x 4 columns]
#       filmeId                              titulo                 genero  nota
# 5554    26696                    Lionheart (1990)                 Action   0.5
# 2689     3604                        Gypsy (1962)                Musical   0.5
# 4881     7312             Follow Me, Boys! (1966)           Comedy|Drama   0.5
# 9117   145724               Idaho Transfer (1973)                 Sci-Fi   0.5
# 7297    76030                      Case 39 (2009)        Horror|Thriller   0.5
# ...       ...                                 ...                    ...   ...
# 5749    30892  In the Realms of the Unreal (2004)  Animation|Documentary   NaN
# 5824    32160            Twentieth Century (1934)                 Comedy   NaN
# 5837    32371           Call Northside 777 (1948)  Crime|Drama|Film-Noir   NaN
# 5957    34482        Browning Version, The (1951)                  Drama   NaN
# 7565    85565                  Chalet Girl (2011)         Comedy|Romance   NaN
#
# [9742 rows x 4 columns]

# %%
filmes_com_media.head()
# Out:
#    filmeId  ...      nota
# 0        1  ...  3.920930
# 1        2  ...  3.431818
# 2        3  ...  3.259615
# 3        4  ...  2.357143
# 4        5  ...  3.071429
#
# [5 rows x 4 columns]

# %%
filmes_com_media.columns = ["filmeId", "titulo", "genero", "media"]

# %%
filmes_com_media.head()
# Out:
#    filmeId  ...     media
# 0        1  ...  3.920930
# 1        2  ...  3.431818
# 2        3  ...  3.259615
# 3        4  ...  2.357143
# 4        5  ...  3.071429
#
# [5 rows x 4 columns]

# %%
filmes_com_media.sort_values("media", ascending=False)
# Out:
#       filmeId  ... media
# 7656    88448  ...   5.0
# 8107   100556  ...   5.0
# 9083   143031  ...   5.0
# 9094   143511  ...   5.0
# 9096   143559  ...   5.0
# ...       ...  ...   ...
# 5749    30892  ...   NaN
# 5824    32160  ...   NaN
# 5837    32371  ...   NaN
# 5957    34482  ...   NaN
# 7565    85565  ...   NaN
#
# [9742 rows x 4 columns]

# %%
filmes_com_media.media.notnull()
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#         ...
# 9737    True
# 9738    True
# 9739    True
# 9740    True
# 9741    True
# Name: media, Length: 9742, dtype: bool

# %%
avaliacoes.query("filmeId == 1")["nota"].plot(kind='hist')

# %%
filmes_com_media.columns = ["filmeId", "titulo", "genero", "nota_media"]

# %% [markdown]
# #Código Após a primeira aula, antes dos desafios

# %%
import pandas as pd
import matplotlib

filmes = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula0/ml-latest-small/movies.csv")
#filmes é um DataFrame
filmes.head()
filmes.columns = ["filmeId", "titulo", "genero"]
print(filmes.head())

avaliacoes = pd.read_csv("https://raw.githubusercontent.com/alura-cursos/introducao-a-data-science/master/aula0/ml-latest-small/ratings.csv")
avaliacoes.head()
print(avaliacoes.head())
print(avaliacoes.shape)

avaliacoes.columns = ["usuarioID", "filmeId", "nota", "momento"]
print("As avaliações do filme um são")
print(avaliacoes.query("filmeId==1").describe())
print("A média das notas é")
print(avaliacoes.query("filmeId==1")["nota"].mean())
print("Descrição das avaliações")
print(avaliacoes.describe())

notas_medias_por_filme = avaliacoes.groupby("filmeId")["nota"].mean()

#não queremos correr o risco de amanhã os filmes não estarem em quantidade exata e ter que alterar o meu código
#filmes["nota_media"] = notas_medias_por_filme
#print(filmes.head())

filmes_com_media = filmes.join(notas_medias_por_filme, on="filmeId")
print(filmes_com_media.head())

avaliacoes.query("filmeId == 1")["nota"].plot(kind='hist')

#Encontrar 18 filmes que não tiveram avaliação - copiado de um colega
print("Número total de filmes:", len(filmes))
print("Número total de filmes avaliados:", len(notas_medias_por_filme))
filmes_avaliados = filmes_com_media.query("nota in @notas_medias_por_filme")
filmes_nao_avaliados = filmes_com_media.query("nota not in @notas_medias_por_filme")
#Para determinar quantos filmes não foram avaliados basta verificar o tamanho desse DataFrame com os filmes não avaliados
print("Quantidade de filmes não avaliados:", len(filmes_nao_avaliados))
print(filmes_nao_avaliados)

#alterando o nome da coluna depois do join  minha solução
filmes_com_media.columns = ["filmeId", "titulo", "genero", "nota_media"]
print(filmes_com_media.sort_values("nota_media", ascending=False))


#desafios
#1) Arredondar as medias para duas casas decimais
#2) Descobrir os Gêneros e quais os valores únicos
#3) Contar quantos filmes tem de cada Gênero
#4) plotar o gráfico de tipo igual a barra apariçoes por gênero
#5)Colocar o número de avaliações por filme, isto é, não só a média mas o TOTAL de votos por filme.
